# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ## Data Set 준비

# %%
train_data = pd.read_csv('train_set.csv', index_col = 0)
test_data = pd.read_csv('test_set.csv', index_col = 0)

# %%
train_data
# Out:
#             date  cabbage   radish   garlic    onion   daikon  cilantro  \
# 0     2021-01-02   713.00   760.00  4182.76  1282.48  2163.33   3862.77
# 1     2021-01-04  1946.90   708.50  4427.22  1381.92  2083.49   3539.80
# 2     2021-01-05  1307.79   996.28  4731.48  1396.43  2316.91   3281.04
# 3     2021-01-06  1942.60  1012.55  4420.99  1484.83  2555.18   3440.97
# 4     2021-01-07  1872.97   694.47  4080.54  1488.01  2740.90   3018.87
# ...          ...      ...      ...      ...      ...      ...       ...
# 1241  2024-12-26  2548.80  1332.04  5217.14  1161.23  1487.55  11351.61
# 1242  2024-12-27  3642.66  1545.93  4674.20  1200.78  1503.53  10328.21
# 1243  2024-12-28  2941.62  1325.48  4317.21  1292.75  1396.15  12691.50
# 1244  2024-12-30  2287.54  2270.71  4904.38  1167.73  1566.44  10164.39
# 1245  2024-12-31  2748.73  1437.33  5366.15  1316.29  1706.60  10211.08
#
#       artichoke
# 0      12340.35
# 1       8773.32
# 2      10148.78
# 3      11108.13
# 4      11615.35
# ...         ...
# 1241   11099.88
# 1242   11454.85
# 1243   11325.36
# 1244   11842.47
# 1245   10514.04
#
# [1246 rows x 8 columns]

# %%
test_data
# Out:
#            date   cabbage   radish   garlic    onion   daikon  cilantro  \
# 0    2025-01-02   4832.75  1217.56  5843.78  1408.03  1580.95  12188.33
# 1    2025-01-03   3110.80  2309.07  4613.04  1281.47  1683.65  12823.14
# 2    2025-01-04   2466.66  2308.51  4664.59  1355.17  1567.71  11395.75
# 3    2025-01-06   3728.57  1671.05  4721.10  1308.74  1659.86  10287.87
# 4    2025-01-07   2640.44  1926.03  5034.74  1430.88  1837.39   8227.55
# ..          ...       ...      ...      ...      ...      ...       ...
# 110  2025-05-15   1948.11  1421.56  3806.53   829.99   797.14   8056.35
# 111  2025-05-16   2310.72  1936.55  4228.17   839.24   805.38   5142.38
# 112  2025-05-17  10743.00   992.69  4385.40   952.11   811.21   6541.44
# 113  2025-05-19   7946.91  1060.81  5659.89   903.22  1089.97   4668.99
# 114  2025-05-20    838.82  1104.04  4813.43   880.42  1085.96   5281.23
#
#      artichoke
# 0     14781.40
# 1     11304.91
# 2     11444.51
# 3     12001.80
# 4     10084.76
# ..         ...
# 110    7504.12
# 111    7484.80
# 112    6750.44
# 113    7030.72
# 114    4492.58
#
# [115 rows x 8 columns]

# %%
# 1월부터 4월까지의 데이터를 활용해 test 진행 예정이기 때문에 5월 데이터는 삭제
test_data['date'] = pd.to_datetime(test_data['date'])
test_data = test_data[test_data['date'].dt.month != 5]
test_data.tail()
# Out:
#          date   cabbage   radish   garlic    onion  daikon  cilantro  \
# 93 2025-04-25   3760.42  2004.59  4116.21  1249.71  670.54   6485.02
# 94 2025-04-26   2156.31  2470.71  3970.21  1284.41  668.11   6097.55
# 95 2025-04-28  32127.52  1485.51  4212.23  1119.54  689.10   5698.70
# 96 2025-04-29   4154.87  1302.11  4651.40  1150.63  767.71   6454.00
# 97 2025-04-30   4740.45  1109.83  4438.43  1149.61  780.90   5330.21
#
#     artichoke
# 93    5548.51
# 94    6511.69
# 95    5424.83
# 96    6009.32
# 97    5582.41

# %% [markdown]
# ## EDA 진행

# %%
print(train_data.info())
print('=' * 50)
print(test_data.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1246 entries, 0 to 1245
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       1246 non-null   object
#  1   cabbage    1240 non-null   float64
#  2   radish     1241 non-null   float64
#  3   garlic     1239 non-null   float64
#  4   onion      1239 non-null   float64
#  5   daikon     1244 non-null   float64
#  6   cilantro   1236 non-null   float64
#  7   artichoke  1239 non-null   float64
# dtypes: float64(7), object(1)
# memory usage: 87.6+ KB
# None
# ==================================================
# <class 'pandas.core.frame.DataFrame'>
# Index: 98 entries, 0 to 97
# Data columns (total 8 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   date       98 non-null     datetime64[ns]
#  1   cabbage    98 non-null     float64
#  2   radish     97 non-null     float64
#  3   garlic     98 non-null     float64
#  4   onion      97 non-null     float64
#  5   daikon     98 non-null     float64
#  6   cilantro   98 non-null     float64
#  7   artichoke  98 non-null     float64
# dtypes: datetime64[ns](1), float64(7)
# memory usage: 6.9 KB
# None

# %%
print(train_data.isnull().sum())
print('=' * 50)
print(test_data.isnull().sum())
# Out:
# date          0
# cabbage       6
# radish        5
# garlic        7
# onion         7
# daikon        2
# cilantro     10
# artichoke     7
# dtype: int64
# ==================================================
# date         0
# cabbage      0
# radish       1
# garlic       0
# onion        1
# daikon       0
# cilantro     0
# artichoke    0
# dtype: int64

# %% [markdown]
# - Nan 값이 존재. 해당 값들을 해당 월의 평균 값으로 대체

# %%
train_data['date'] = pd.to_datetime(train_data['date'])
train_data['year_month'] = train_data['date'].dt.to_period('M')

test_data['date'] = pd.to_datetime(test_data['date'])
test_data['year_month'] = test_data['date'].dt.to_period('M')

rows = train_data.isna().any(axis=1)
print(train_data[rows].head())
# Out:
#           date  cabbage  radish   garlic   onion   daikon  cilantro  \
# 31  2021-02-07   553.20  356.68      NaN  1030.0  3772.44       NaN
# 223 2021-09-20  2985.97  576.81  6959.62     NaN  1441.37   1706.55
# 336 2022-02-03  1668.21  435.42  6796.20   450.0  1904.38       NaN
# 411 2022-05-01      NaN     NaN  8100.00     NaN      NaN       NaN
# 424 2022-05-15      NaN     NaN  5440.00     NaN      NaN       NaN
#
#      artichoke year_month
# 31     7213.89    2021-02
# 223    5121.82    2021-09
# 336   11550.61    2022-02
# 411        NaN    2022-05
# 424        NaN    2022-05
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_255760\2985041201.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['date'] = pd.to_datetime(test_data['date'])
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_255760\2985041201.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data['year_month'] = test_data['date'].dt.to_period('M')

# %%
# test 데이터 속 cilantror != cilantro
test_data.columns = train_data.columns

features = train_data.drop(columns=['date','year_month']).columns

for feature in features:
    #------------train data--------------
    train_avg_month = train_data.groupby('year_month')[feature].mean().round(2)
    train_rows_NaN_feature = train_data[train_data[feature].isna()].index
    
    for idx in train_rows_NaN_feature:
        year_month = train_data.at[idx, 'year_month']
        if pd.notna(train_avg_month.get(year_month)):  
            train_data.at[idx, feature] = train_avg_month[year_month]
            
    #------------test data--------------
    test_avg_month = test_data.groupby('year_month')[feature].mean().round(2)
    test_rows_NaN_feature = test_data[test_data[feature].isna()].index
    
    for idx in test_rows_NaN_feature:
        year_month = test_data.at[idx, 'year_month']
        if pd.notna(test_avg_month.get(year_month)):  
            test_data.at[idx, feature] = test_avg_month[year_month]

# %%
print(train_data[rows].head())
# Out:
#           date  cabbage  radish   garlic    onion   daikon  cilantro  \
# 31  2021-02-07   553.20  356.68  4415.75  1030.00  3772.44   4243.76
# 223 2021-09-20  2985.97  576.81  6959.62   893.28  1441.37   1706.55
# 336 2022-02-03  1668.21  435.42  6796.20   450.00  1904.38   4907.77
# 411 2022-05-01  2429.81  918.75  8100.00   635.36  1295.08   5041.66
# 424 2022-05-15  2429.81  918.75  5440.00   635.36  1295.08   5041.66
#
#      artichoke year_month
# 31     7213.89    2021-02
# 223    5121.82    2021-09
# 336   11550.61    2022-02
# 411    6634.13    2022-05
# 424    6634.13    2022-05

# %%
train_data.drop(columns='year_month', inplace=True)
test_data.drop(columns='year_month', inplace=True)
# Out:
# C:\Users\Public\Documents\ESTsoft\CreatorTemp\ipykernel_255760\4112785324.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_data.drop(columns='year_month', inplace=True)

# %%
print(train_data.isnull().sum())
print('=' * 50)
print(test_data.isnull().sum())
# Out:
# date         0
# cabbage      0
# radish       0
# garlic       0
# onion        0
# daikon       0
# cilantro     0
# artichoke    0
# dtype: int64
# ==================================================
# date         0
# cabbage      0
# radish       0
# garlic       0
# onion        0
# daikon       0
# cilantro     0
# artichoke    0
# dtype: int64

# %%
import matplotlib.font_manager as fm
import matplotlib.pyplot as plt

train_data.set_index('date').plot(figsize = (14, 6))

plt.title("The trend of the price columns")
plt.xlabel("Date")
plt.ylabel("Price")
plt.show()

# %%
def calculate_rolling_mean(data, window = 7):
    data_rolling_mean = data.drop(columns = ['date']).rolling(window = window, min_periods = 1).mean()

    data_rolling_mean['date'] = data['date']

    return data_rolling_mean

train_data_roll = calculate_rolling_mean(train_data)

# %%
train_data_roll.set_index('date').plot(figsize = (14, 6))

plt.title("The trend of the price columns after rollinh mean")
plt.xlabel('Date')
plt.ylabel('Price')
plt.show()

# %%
import seaborn as sns

plt.figure(figsize = (8, 5))

sns.histplot(train_data['cabbage'], bins = 10, kde = True, label = 'cabbage', color = 'blue', edgecolor = 'black')
sns.histplot(train_data['radish'], bins = 10, kde = True, label = 'radish', color = 'red', edgecolor = 'black')
sns.histplot(train_data['garlic'], bins = 10, kde = True, label = 'garlic', color = 'yellow', edgecolor = 'black')
sns.histplot(train_data['onion'], bins = 10, kde = True, label = 'onion', color = 'green', edgecolor = 'black')

plt.title('Distribution of prices', fontsize = 12)
plt.xlabel('Price', fontsize = 10)
plt.ylabel('Density', fontsize = 10)
plt.legend()
plt.show()
# Out:
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize = (8, 5))

sns.histplot(train_data['daikon'], bins = 10, kde = True, label = 'daikon', color = 'purple', edgecolor = 'black')
sns.histplot(train_data['cilantro'], bins = 10, kde = True, label = 'cilantro', color = 'pink', edgecolor = 'black')
sns.histplot(train_data['artichoke'], bins = 10, kde = True, label = 'artichoke', color = 'orange', edgecolor = 'black')

plt.title('Distribution of prices', fontsize = 12)
plt.xlabel('Price', fontsize = 10)
plt.ylabel('Density', fontsize = 10)
plt.legend()
plt.show()
# Out:
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\kjw02\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
train_data_analysis = train_data.copy()
train_data_analysis['date'] = pd.to_datetime(train_data['date'])
train_data_analysis['day'] = train_data['date'].dt.day_of_week
train_data_analysis['month'] = train_data['date'].dt.month

price_by_day = train_data_analysis.groupby("day")[['cabbage', 'radish', 'garlic', 'onion', 'daikon', 'cilantro', 'artichoke']].mean().round(2)
price_by_month = train_data_analysis.groupby("month")[['cabbage', 'radish', 'garlic', 'onion', 'daikon', 'cilantro', 'artichoke']].mean().round(2)

# %%
price_by_day.T.plot(kind = 'bar', figsize = (12, 5))
plt.title('Average Price by Day of Week')
plt.xlabel('Day of Week')
plt.ylabel('Average Price')
plt.show()

# %%
price_by_month.T.plot(kind = 'bar', figsize = (12, 5))

plt.title("Average Price by Month")
plt.xlabel("Month")
plt.ylabel("Average Price")
plt.show()

# %%
# Day, Month는 무시

cor_matrix_train = train_data_analysis.corr()[1:].drop('date', axis = 1)
cor_matrix_train.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_05056_row0_col0, #T_05056_row1_col1, #T_05056_row2_col2, #T_05056_row3_col3, #T_05056_row4_col4, #T_05056_row5_col5, #T_05056_row6_col6, #T_05056_row7_col7, #T_05056_row8_col8 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_05056_row0_col1, #T_05056_row6_col1 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_05056_row0_col2 {
#   background-color: #6485ec;
#   color: #f1f1f1;
# }
# #T_05056_row0_col3 {
#   background-color: #5d7ce6;
#   color: #f1f1f1;
# }
# #T_05056_row0_col4 {
#   background-color: #7396f5;
#   color: #f1f1f1;
# }
# #T_05056_row0_col5, #T_05056_row5_col4 {
#   background-color: #9fbfff;
#   color: #000000;
# }
# #T_05056_row0_col6, #T_05056_row4_col5 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_05056_row0_col7, #T_05056_row7_col3 {
#   background-color: #3e51c5;
#   color: #f1f1f1;
# }
# #T_05056_row0_col8, #T_05056_row7_col8 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_05056_row1_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_05056_row1_col2, #T_05056_row5_col0, #T_05056_row7_col4 {
#   background-color: #7a9df8;
#   color: #f1f1f1;
# }
# #T_05056_row1_col3, #T_05056_row2_col6 {
#   background-color: #8caffe;
#   color: #000000;
# }
# #T_05056_row1_col4 {
#   background-color: #9dbdff;
#   color: #000000;
# }
# #T_05056_row1_col5 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_05056_row1_col6 {
#   background-color: #b3cdfb;
#   color: #000000;
# }
# #T_05056_row1_col7 {
#   background-color: #5977e3;
#   color: #f1f1f1;
# }
# #T_05056_row1_col8 {
#   background-color: #7ea1fa;
#   color: #f1f1f1;
# }
# #T_05056_row2_col0, #T_05056_row2_col1, #T_05056_row2_col5, #T_05056_row3_col7, #T_05056_row4_col8, #T_05056_row5_col2, #T_05056_row5_col6, #T_05056_row8_col1, #T_05056_row8_col3, #T_05056_row8_col4 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_05056_row2_col3, #T_05056_row5_col7, #T_05056_row8_col5, #T_05056_row8_col6 {
#   background-color: #4055c8;
#   color: #f1f1f1;
# }
# #T_05056_row2_col4 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_05056_row2_col7 {
#   background-color: #3f53c6;
#   color: #f1f1f1;
# }
# #T_05056_row2_col8 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_05056_row3_col0 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_05056_row3_col1, #T_05056_row6_col8 {
#   background-color: #7da0f9;
#   color: #f1f1f1;
# }
# #T_05056_row3_col2 {
#   background-color: #7093f3;
#   color: #f1f1f1;
# }
# #T_05056_row3_col4 {
#   background-color: #f7bca1;
#   color: #000000;
# }
# #T_05056_row3_col5 {
#   background-color: #d3dbe7;
#   color: #000000;
# }
# #T_05056_row3_col6, #T_05056_row7_col5 {
#   background-color: #7597f6;
#   color: #f1f1f1;
# }
# #T_05056_row3_col8 {
#   background-color: #6f92f3;
#   color: #f1f1f1;
# }
# #T_05056_row4_col0 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_05056_row4_col1 {
#   background-color: #5b7ae5;
#   color: #f1f1f1;
# }
# #T_05056_row4_col2, #T_05056_row8_col0 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_05056_row4_col3 {
#   background-color: #f0cdbb;
#   color: #000000;
# }
# #T_05056_row4_col6 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_05056_row4_col7 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_05056_row5_col1 {
#   background-color: #5572df;
#   color: #f1f1f1;
# }
# #T_05056_row5_col3 {
#   background-color: #b6cefa;
#   color: #000000;
# }
# #T_05056_row5_col8 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_05056_row6_col0 {
#   background-color: #a5c3fe;
#   color: #000000;
# }
# #T_05056_row6_col2 {
#   background-color: #b9d0f9;
#   color: #000000;
# }
# #T_05056_row6_col3 {
#   background-color: #7b9ff9;
#   color: #f1f1f1;
# }
# #T_05056_row6_col4 {
#   background-color: #a3c2fe;
#   color: #000000;
# }
# #T_05056_row6_col5, #T_05056_row7_col2 {
#   background-color: #7295f4;
#   color: #f1f1f1;
# }
# #T_05056_row6_col7, #T_05056_row8_col7 {
#   background-color: #4961d2;
#   color: #f1f1f1;
# }
# #T_05056_row7_col0 {
#   background-color: #485fd1;
#   color: #f1f1f1;
# }
# #T_05056_row7_col1 {
#   background-color: #4c66d6;
#   color: #f1f1f1;
# }
# #T_05056_row7_col6 {
#   background-color: #455cce;
#   color: #f1f1f1;
# }
# #T_05056_row8_col2 {
#   background-color: #c1d4f4;
#   color: #000000;
# }
# </style>
# <table id="T_05056">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_05056_level0_col0" class="col_heading level0 col0" >cabbage</th>
#       <th id="T_05056_level0_col1" class="col_heading level0 col1" >radish</th>
#       <th id="T_05056_level0_col2" class="col_heading level0 col2" >garlic</th>
#       <th id="T_05056_level0_col3" class="col_heading level0 col3" >onion</th>
#       <th id="T_05056_level0_col4" class="col_heading level0 col4" >daikon</th>
#       <th id="T_05056_level0_col5" class="col_heading level0 col5" >cilantro</th>
#       <th id="T_05056_level0_col6" class="col_heading level0 col6" >artichoke</th>
#       <th id="T_05056_level0_col7" class="col_heading level0 col7" >day</th>
#       <th id="T_05056_level0_col8" class="col_heading level0 col8" >month</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_05056_level0_row0" class="row_heading level0 row0" >cabbage</th>
#       <td id="T_05056_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_05056_row0_col1" class="data row0 col1" >0.339659</td>
#       <td id="T_05056_row0_col2" class="data row0 col2" >-0.085639</td>
#       <td id="T_05056_row0_col3" class="data row0 col3" >0.053447</td>
#       <td id="T_05056_row0_col4" class="data row0 col4" >-0.050555</td>
#       <td id="T_05056_row0_col5" class="data row0 col5" >0.127825</td>
#       <td id="T_05056_row0_col6" class="data row0 col6" >0.259864</td>
#       <td id="T_05056_row0_col7" class="data row0 col7" >-0.036280</td>
#       <td id="T_05056_row0_col8" class="data row0 col8" >-0.000250</td>
#     </tr>
#     <tr>
#       <th id="T_05056_level0_row1" class="row_heading level0 row1" >radish</th>
#       <td id="T_05056_row1_col0" class="data row1 col0" >0.339659</td>
#       <td id="T_05056_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_05056_row1_col2" class="data row1 col2" >-0.006457</td>
#       <td id="T_05056_row1_col3" class="data row1 col3" >0.200517</td>
#       <td id="T_05056_row1_col4" class="data row1 col4" >0.101324</td>
#       <td id="T_05056_row1_col5" class="data row1 col5" >0.080207</td>
#       <td id="T_05056_row1_col6" class="data row1 col6" >0.339039</td>
#       <td id="T_05056_row1_col7" class="data row1 col7" >0.053851</td>
#       <td id="T_05056_row1_col8" class="data row1 col8" >-0.007680</td>
#     </tr>
#     <tr>
#       <th id="T_05056_level0_row2" class="row_heading level0 row2" >garlic</th>
#       <td id="T_05056_row2_col0" class="data row2 col0" >-0.085639</td>
#       <td id="T_05056_row2_col1" class="data row2 col1" >-0.006457</td>
#       <td id="T_05056_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_05056_row2_col3" class="data row2 col3" >-0.041142</td>
#       <td id="T_05056_row2_col4" class="data row2 col4" >-0.154355</td>
#       <td id="T_05056_row2_col5" class="data row2 col5" >-0.253576</td>
#       <td id="T_05056_row2_col6" class="data row2 col6" >0.221336</td>
#       <td id="T_05056_row2_col7" class="data row2 col7" >-0.033893</td>
#       <td id="T_05056_row2_col8" class="data row2 col8" >0.253794</td>
#     </tr>
#     <tr>
#       <th id="T_05056_level0_row3" class="row_heading level0 row3" >onion</th>
#       <td id="T_05056_row3_col0" class="data row3 col0" >0.053447</td>
#       <td id="T_05056_row3_col1" class="data row3 col1" >0.200517</td>
#       <td id="T_05056_row3_col2" class="data row3 col2" >-0.041142</td>
#       <td id="T_05056_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_05056_row3_col4" class="data row3 col4" >0.559508</td>
#       <td id="T_05056_row3_col5" class="data row3 col5" >0.327882</td>
#       <td id="T_05056_row3_col6" class="data row3 col6" >0.151178</td>
#       <td id="T_05056_row3_col7" class="data row3 col7" >-0.051554</td>
#       <td id="T_05056_row3_col8" class="data row3 col8" >-0.064181</td>
#     </tr>
#     <tr>
#       <th id="T_05056_level0_row4" class="row_heading level0 row4" >daikon</th>
#       <td id="T_05056_row4_col0" class="data row4 col0"

# %%
cor_matrix_test = test_data.corr()[1:].drop('date', axis = 1)
cor_matrix_test.style.background_gradient(cmap = 'coolwarm')
# Out:
# <style type="text/css">
# #T_e13f2_row0_col0, #T_e13f2_row1_col1, #T_e13f2_row2_col2, #T_e13f2_row3_col3, #T_e13f2_row4_col4, #T_e13f2_row5_col5, #T_e13f2_row6_col6 {
#   background-color: #b40426;
#   color: #f1f1f1;
# }
# #T_e13f2_row0_col1, #T_e13f2_row0_col2, #T_e13f2_row0_col6, #T_e13f2_row4_col0, #T_e13f2_row4_col5, #T_e13f2_row5_col1, #T_e13f2_row5_col4, #T_e13f2_row6_col3 {
#   background-color: #3b4cc0;
#   color: #f1f1f1;
# }
# #T_e13f2_row0_col3, #T_e13f2_row0_col4 {
#   background-color: #4f69d9;
#   color: #f1f1f1;
# }
# #T_e13f2_row0_col5 {
#   background-color: #cbd8ee;
#   color: #000000;
# }
# #T_e13f2_row1_col0 {
#   background-color: #6c8ff1;
#   color: #f1f1f1;
# }
# #T_e13f2_row1_col2 {
#   background-color: #5673e0;
#   color: #f1f1f1;
# }
# #T_e13f2_row1_col3, #T_e13f2_row6_col2 {
#   background-color: #93b5fe;
#   color: #000000;
# }
# #T_e13f2_row1_col4, #T_e13f2_row4_col3 {
#   background-color: #c5d6f2;
#   color: #000000;
# }
# #T_e13f2_row1_col5 {
#   background-color: #81a4fb;
#   color: #f1f1f1;
# }
# #T_e13f2_row1_col6, #T_e13f2_row5_col6 {
#   background-color: #799cf8;
#   color: #f1f1f1;
# }
# #T_e13f2_row2_col0 {
#   background-color: #5875e1;
#   color: #f1f1f1;
# }
# #T_e13f2_row2_col1 {
#   background-color: #4257c9;
#   color: #f1f1f1;
# }
# #T_e13f2_row2_col3 {
#   background-color: #86a9fc;
#   color: #f1f1f1;
# }
# #T_e13f2_row2_col4 {
#   background-color: #cedaeb;
#   color: #000000;
# }
# #T_e13f2_row2_col5 {
#   background-color: #b2ccfb;
#   color: #000000;
# }
# #T_e13f2_row2_col6 {
#   background-color: #a2c1ff;
#   color: #000000;
# }
# #T_e13f2_row3_col0 {
#   background-color: #82a6fb;
#   color: #f1f1f1;
# }
# #T_e13f2_row3_col1 {
#   background-color: #94b6ff;
#   color: #000000;
# }
# #T_e13f2_row3_col2 {
#   background-color: #9abbff;
#   color: #000000;
# }
# #T_e13f2_row3_col4 {
#   background-color: #e8d6cc;
#   color: #000000;
# }
# #T_e13f2_row3_col5 {
#   background-color: #8badfd;
#   color: #000000;
# }
# #T_e13f2_row3_col6 {
#   background-color: #6282ea;
#   color: #f1f1f1;
# }
# #T_e13f2_row4_col1 {
#   background-color: #8fb1fe;
#   color: #000000;
# }
# #T_e13f2_row4_col2 {
#   background-color: #aec9fc;
#   color: #000000;
# }
# #T_e13f2_row4_col6 {
#   background-color: #dcdddd;
#   color: #000000;
# }
# #T_e13f2_row5_col0 {
#   background-color: #bed2f6;
#   color: #000000;
# }
# #T_e13f2_row5_col2 {
#   background-color: #88abfd;
#   color: #000000;
# }
# #T_e13f2_row5_col3 {
#   background-color: #445acc;
#   color: #f1f1f1;
# }
# #T_e13f2_row6_col0 {
#   background-color: #465ecf;
#   color: #f1f1f1;
# }
# #T_e13f2_row6_col1 {
#   background-color: #536edd;
#   color: #f1f1f1;
# }
# #T_e13f2_row6_col4 {
#   background-color: #ead5c9;
#   color: #000000;
# }
# #T_e13f2_row6_col5 {
#   background-color: #97b8ff;
#   color: #000000;
# }
# </style>
# <table id="T_e13f2">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e13f2_level0_col0" class="col_heading level0 col0" >cabbage</th>
#       <th id="T_e13f2_level0_col1" class="col_heading level0 col1" >radish</th>
#       <th id="T_e13f2_level0_col2" class="col_heading level0 col2" >garlic</th>
#       <th id="T_e13f2_level0_col3" class="col_heading level0 col3" >onion</th>
#       <th id="T_e13f2_level0_col4" class="col_heading level0 col4" >daikon</th>
#       <th id="T_e13f2_level0_col5" class="col_heading level0 col5" >cilantro</th>
#       <th id="T_e13f2_level0_col6" class="col_heading level0 col6" >artichoke</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e13f2_level0_row0" class="row_heading level0 row0" >cabbage</th>
#       <td id="T_e13f2_row0_col0" class="data row0 col0" >1.000000</td>
#       <td id="T_e13f2_row0_col1" class="data row0 col1" >-0.054484</td>
#       <td id="T_e13f2_row0_col2" class="data row0 col2" >-0.134288</td>
#       <td id="T_e13f2_row0_col3" class="data row0 col3" >0.021589</td>
#       <td id="T_e13f2_row0_col4" class="data row0 col4" >-0.252919</td>
#       <td id="T_e13f2_row0_col5" class="data row0 col5" >0.240053</td>
#       <td id="T_e13f2_row0_col6" class="data row0 col6" >-0.203422</td>
#     </tr>
#     <tr>
#       <th id="T_e13f2_level0_row1" class="row_heading level0 row1" >radish</th>
#       <td id="T_e13f2_row1_col0" class="data row1 col0" >-0.054484</td>
#       <td id="T_e13f2_row1_col1" class="data row1 col1" >1.000000</td>
#       <td id="T_e13f2_row1_col2" class="data row1 col2" >-0.031106</td>
#       <td id="T_e13f2_row1_col3" class="data row1 col3" >0.230357</td>
#       <td id="T_e13f2_row1_col4" class="data row1 col4" >0.212456</td>
#       <td id="T_e13f2_row1_col5" class="data row1 col5" >-0.055945</td>
#       <td id="T_e13f2_row1_col6" class="data row1 col6" >0.030531</td>
#     </tr>
#     <tr>
#       <th id="T_e13f2_level0_row2" class="row_heading level0 row2" >garlic</th>
#       <td id="T_e13f2_row2_col0" class="data row2 col0" >-0.134288</td>
#       <td id="T_e13f2_row2_col1" class="data row2 col1" >-0.031106</td>
#       <td id="T_e13f2_row2_col2" class="data row2 col2" >1.000000</td>
#       <td id="T_e13f2_row2_col3" class="data row2 col3" >0.192452</td>
#       <td id="T_e13f2_row2_col4" class="data row2 col4" >0.256041</td>
#       <td id="T_e13f2_row2_col5" class="data row2 col5" >0.133909</td>
#       <td id="T_e13f2_row2_col6" class="data row2 col6" >0.171338</td>
#     </tr>
#     <tr>
#       <th id="T_e13f2_level0_row3" class="row_heading level0 row3" >onion</th>
#       <td id="T_e13f2_row3_col0" class="data row3 col0" >0.021589</td>
#       <td id="T_e13f2_row3_col1" class="data row3 col1" >0.230357</td>
#       <td id="T_e13f2_row3_col2" class="data row3 col2" >0.192452</td>
#       <td id="T_e13f2_row3_col3" class="data row3 col3" >1.000000</td>
#       <td id="T_e13f2_row3_col4" class="data row3 col4" >0.385015</td>
#       <td id="T_e13f2_row3_col5" class="data row3 col5" >-0.015521</td>
#       <td id="T_e13f2_row3_col6" class="data row3 col6" >-0.051188</td>
#     </tr>
#     <tr>
#       <th id="T_e13f2_level0_row4" class="row_heading level0 row4" >daikon</th>
#       <td id="T_e13f2_row4_col0" class="data row4 col0" >-0.252919</td>
#       <td id="T_e13f2_row4_col1" class="data row4 col1" >0.212456</td>
#       <td id="T_e13f2_row4_col2" class="data row4 col2" >0.256041</td>
#       <td id="T_e13f2_row4_col3" class="data row4 col3" >0.385015</td>
#       <td id="T_e13f2_row4_col4" class="data row4 col4" >1.000000</td>
#       <td id="T_e13f2_row4_col5" class="data row4 col5" >-0.345792</td>
#       <td id="T_e13f2_row4_col6" class="data row4 col6" >0.396517</td>
#     </tr>
#     <tr>
#       <th id="T_e13f2_level0_row5" class="row_heading level0 row5" >cilantro</th>
#       <td id="T_e13f2_row5_col0" class="data row5 col0" >0.240053</td>
#       <td id="T_e13f2_row5_col1" class="data row5 col1" >-0.055945</td>
#       <td id="T_e13f2_row5_col2" class="data row5 col2" >0.133909</td>
#       <td id="T_e13f2_row5_col3" class="data row5 col3" >-0.015521</td>
#       <td id="T_e13f2_row5_col4" class="data row5 col4" >-0.345792</td>
#       <td id="T_e13f2_row5_col5" class="data row5 col5" >1.000000</td>
#       <td id="T_e13f2_row5_col6" class="data row5 col6" >0.028393</td>
#     </tr>
#     <tr>
#       <th id="T_e13f2_level0_row6" class="row_heading level0 row6" >artichoke</th>
#       <td id="T_e13f2_row6_col0" class="data row6 col0" >-0.203422</td>
#       <td id="T_e13f2_row6_col1" class="data row6 col1" >0.030531</td>
#       <td id="T_e13f2_row6_col2" class="data row6 col2" >0.171338</td>
#       <td id="T_e13f2_row6_col3" class="data row6 col3" >-0.051188</td>
#       <td id="T_e13f2_row6_col4" class="data row6 col4" >0.396517</td>
#       <td id="T_e13f2_row6_col5" class="data row6 col5" >0.028393</td>
#       <td id="T_e13f2_row6_col6" class="data row6 col6" >1.000000</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Construct baseline model

# %% [markdown]
# - 시계열 알고리즘과 ML 알고리즘 모두 구현해볼 예정
# - 해당 데이터는 시계열 데이터로써 시계열 알고리즘의 성능도 어느정도 기대해볼 수 있음
# - 시계열 알고리즘의 경우 Prophet을 사용 예정
# - ML 알고리즘의 경우 Feature의 퀄리티에 따라 성능에 영향이 가기 때문에 Feature Engineering 과정이 중요
# - ML 알고리즘의 경우 Linear Regression, Ridge, Lasso, RandomForest, LGBM, XGBOOST를 사용하여 사용자가 다양한 모델을 사용할 수 있도록 할 예정

# %% [markdown]
# ### Prophet을 이용한 시계열 데이터 예측

# %%
# 이미 설치가 되었다면 주석처리하고 패스
# pip install prophet

import logging
import warnings
warnings.filterwarnings('ignore')

from prophet import Prophet
logging.getLogger('prophet').setLevel(logging.WARNING)


# train dataset
print(train_data.head())

# test dataset
print(test_data.head())
# Out:
#         date  cabbage   radish   garlic    onion   daikon  cilantro  artichoke
# 0 2021-01-02   713.00   760.00  4182.76  1282.48  2163.33   3862.77   12340.35
# 1 2021-01-04  1946.90   708.50  4427.22  1381.92  2083.49   3539.80    8773.32
# 2 2021-01-05  1307.79   996.28  4731.48  1396.43  2316.91   3281.04   10148.78
# 3 2021-01-06  1942.60  1012.55  4420.99  1484.83  2555.18   3440.97   11108.13
# 4 2021-01-07  1872.97   694.47  4080.54  1488.01  2740.90   3018.87   11615.35
#         date  cabbage   radish   garlic    onion   daikon  cilantro  artichoke
# 0 2025-01-02  4832.75  1217.56  5843.78  1408.03  1580.95  12188.33   14781.40
# 1 2025-01-03  3110.80  2309.07  4613.04  1281.47  1683.65  12823.14   11304.91
# 2 2025-01-04  2466.66  2308.51  4664.59  1355.17  1567.71  11395.75   11444.51
# 3 2025-01-06  3728.57  1671.05  4721.10  1308.74  1659.86  10287.87   12001.80
# 4 2025-01-07  2640.44  1926.03  5034.74  1430.88  1837.39   8227.55   10084.76

# %%
# 예측 대상 df 생성
start_dt= '2025-01-02'
end_dt = '2025-04-30'
forecast_df = pd.DataFrame({'date':pd.date_range(start = start_dt, end = end_dt)})
forecast_df
# Out:
#           date
# 0   2025-01-02
# 1   2025-01-03
# 2   2025-01-04
# 3   2025-01-05
# 4   2025-01-06
# ..         ...
# 114 2025-04-26
# 115 2025-04-27
# 116 2025-04-28
# 117 2025-04-29
# 118 2025-04-30
#
# [119 rows x 1 columns]

# %% [markdown]
# **해당 데이터에는 이미 휴일 및 일요일 날짜의 데이터가 빠져있기 때문에 따로 작업하지 않음</br>
# 만약 휴일과 관련된 데이터 들이있을 경우</br>
# holiday 라이브러리를 import하여 휴일과 일요일에 대한 데이터를 처리**

# %%
# 품목별 반복하면서 예측 후 저장

for col in train_data.columns:
    if col != 'date':
        train_prophet = train_data[['date', col]].rename(columns = {'date': 'ds', col: 'y'})
        
        model_prophet = Prophet()
        model_prophet.fit(train_prophet)
        
        future_dates = pd.DataFrame(pd.date_range(start = start_dt, end = end_dt), columns = ['ds'])
        forecast = model_prophet.predict(future_dates)
        forecast = forecast.round(2)
        forecast_df[col + '_pred'] = forecast['yhat']
# Out:
# 20:07:51 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:51 - cmdstanpy - INFO - Chain [1] done processing
# 20:07:52 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:52 - cmdstanpy - INFO - Chain [1] done processing
# 20:07:52 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:52 - cmdstanpy - INFO - Chain [1] done processing
# 20:07:52 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 20:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 20:07:53 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:53 - cmdstanpy - INFO - Chain [1] done processing
# 20:07:54 - cmdstanpy - INFO - Chain [1] start processing
# 20:07:54 - cmdstanpy - INFO - Chain [1] done processing

# %%
forecast_df.head()
# Out:
#         date  cabbage_pred  radish_pred  garlic_pred  onion_pred  daikon_pred  \
# 0 2025-01-02       3189.32      1684.85      4428.27     1210.99      1436.55
# 1 2025-01-03       3246.85      1705.71      4310.12     1165.00      1408.19
# 2 2025-01-04       3252.01      1728.27      4131.92     1151.11      1379.71
# 3 2025-01-05       2891.39      1533.66      4362.05     1041.82      1110.61
# 4 2025-01-06       3315.39      1614.74      4242.45     1174.20      1370.42
#
#    cilantro_pred  artichoke_pred
# 0        7388.27        11846.43
# 1        7395.24        11978.47
# 2        7193.74        11643.78
# 3        7137.62        11596.99
# 4        7228.65        11672.06

# %%
forecast_df.tail()
# Out:
#           date  cabbage_pred  radish_pred  garlic_pred  onion_pred  \
# 114 2025-04-26       3872.47      1474.13      3402.67     1042.96
# 115 2025-04-27       3491.93      1284.02      3636.67      927.17
# 116 2025-04-28       3897.35      1369.42      3519.37     1053.07
# 117 2025-04-29       3836.39      1373.37      3625.65     1099.88
# 118 2025-04-30       3728.40      1426.33      3689.21     1031.38
#
#      daikon_pred  cilantro_pred  artichoke_pred
# 114       969.29       11317.97         6782.86
# 115       718.61       11140.95         6797.62
# 116       994.87       11109.75         6947.16
# 117       980.50       10893.89         6900.44
# 118       938.17       10590.46         6838.30

# %%
test_data.head()
# Out:
#         date  cabbage   radish   garlic    onion   daikon  cilantro  artichoke
# 0 2025-01-02  4832.75  1217.56  5843.78  1408.03  1580.95  12188.33   14781.40
# 1 2025-01-03  3110.80  2309.07  4613.04  1281.47  1683.65  12823.14   11304.91
# 2 2025-01-04  2466.66  2308.51  4664.59  1355.17  1567.71  11395.75   11444.51
# 3 2025-01-06  3728.57  1671.05  4721.10  1308.74  1659.86  10287.87   12001.80
# 4 2025-01-07  2640.44  1926.03  5034.74  1430.88  1837.39   8227.55   10084.76

# %%
test = test_data.merge(forecast_df, on=['date'], how = 'left')

# %%
# 품목별로 실제, 예측 값만 저장

prd = ['cabbage', 'radish', 'garlic', 'onion', 'daikon', 'cilantro', 'artichoke']
dfs = {}
for p in prd:
    dfs[p] = test[['date', p, p+'_pred']]
    
print("DataFrame for garlic")
print(dfs['garlic'].head())
# Out:
# DataFrame for garlic
#         date   garlic  garlic_pred
# 0 2025-01-02  5843.78      4428.27
# 1 2025-01-03  4613.04      4310.12
# 2 2025-01-04  4664.59      4131.92
# 3 2025-01-06  4721.10      4242.45
# 4 2025-01-07  5034.74      4348.21

# %%
# 픔목별 예측값 vs 실제값 시각화
num_rows = 3
num_cols = 3
fig, axes = plt.subplots(num_rows, num_cols, figsize = (12,8))
axes = axes.flatten()

# 품목 목록
products = ['cabbage', 'radish', 'garlic', 'onion', 'daikon', 'cilantro', 'artichoke']

for i, (prd, ax) in enumerate(zip(products, axes)):
    df = dfs[prd]
    ax.plot(df['date'], df[prd], label = 'Actual')
    ax.plot(df['date'], df[prd+'_pred'], label = 'Predicted')
    ax.set_title(prd)
    ax.legend()
    ax.tick_params(axis = 'x', labelsize = 6)
    
plt.tight_layout()
plt.show()

# %% [markdown]
# - Post Processing 진행하려 했지만 해당 데이터에는 휴일(일요일, 공휴일 등)의 데이터가 부재</br>또한 모든 농산물의 가격이 동일한 시기에 오르거나 내려가지 않고 따로따로 변동되는것으로 보아 크게 영향을 주는 event가 없다고 판단

# %%
prd = ['cabbage', 'radish', 'garlic', 'onion', 'daikon', 'cilantro', 'artichoke']
dfs = {}
for p in prd:
  dfs[p] =  test[['date', p, p+'_pred']]
  dfs[p]['gap'] = dfs[p][p] - dfs[p][p+'_pred']
  dfs[p]['abs_gap'] = abs(dfs[p][p] - dfs[p][p+'_pred'])
  dfs[p]['ape'] = dfs[p]['abs_gap'] / dfs[p][p]
  dfs[p]['ape_median'] = 1 - dfs[p]['ape'].median()

for p in prd:
  print(f"{p}: APE Median = {dfs[p]['ape_median'][0]}")
# Out:
# cabbage: APE Median = 0.7405165845403318
# radish: APE Median = 0.8259838596460858
# garlic: APE Median = 0.8490599994739403
# onion: APE Median = 0.8328846182415658
# daikon: APE Median = 0.8763204036643192
# cilantro: APE Median = 0.318558770276123
# artichoke: APE Median = 0.9019223199938551

# %% [markdown]
# - APE Median 값을 1에서 빼주어 높은 값일 수록 정확도가 올라가는 것으로 표현
# - cilantro를 제외하고는 전부 안정적인 수치를 보여줌

# %% [markdown]
# ### Feature Engineering for ML
